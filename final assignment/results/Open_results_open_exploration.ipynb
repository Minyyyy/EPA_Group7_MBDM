# %%
import pandas as pd

# %%
# import results
from ema_workbench import load_results
experiments_p, outcomes_p = load_results('open_exploration_location_disagg.tar.gz')
outcomes_df_p = pd.DataFrame.from_dict(outcomes_p)
outcomes_df_p.head()
# Out:
#    A.1 Total Costs  A.1_Expected Number of Deaths  A.2 Total Costs  \
# 0     1.724267e+08                            0.0     2.176272e+08
# 1     1.724267e+08                            0.0     2.176272e+08
# 2     1.724267e+08                            0.0     2.176272e+08
# 3     1.724267e+08                            0.0     2.176272e+08
# 4     1.724267e+08                            0.0     2.176272e+08
#
#    A.2_Expected Number of Deaths  A.3 Total Costs  \
# 0                            0.0     7.523979e+07
# 1                            0.0     7.523979e+07
# 2                            0.0     7.871613e+07
# 3                            0.0     1.546602e+08
# 4                            0.0     7.523979e+07
#
#    A.3_Expected Number of Deaths  A.4 Total Costs  \
# 0                       0.000000     5.008544e+07
# 1                       0.000000     4.042333e+07
# 2                       0.004601     3.963509e+07
# 3                       0.097951     5.338119e+07
# ...

# %%
outcomes_df_p = pd.DataFrame.from_dict(experiments_p)
outcomes_df_p.head()
# Out:
#    A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                       24   46.535452       1.0   0.602093  276.615394
# 1                       46  200.984304      10.0   0.288185   38.429487
# 2                      113  251.785018       1.5   0.814699  112.838195
# 3                      122  141.485917       1.0   0.833625  203.302453
# 4                       69   59.492120      10.0   0.089200  294.350816
#
#   A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0      10.0   0.964217   42.486579      10.0   0.973824  ...
# 1       1.0   0.312549  248.774938       1.0   0.363628  ...
# 2       1.5   0.355769  336.092351       1.5   0.196930  ...
# 3       1.0   0.121212  133.096225      10.0   0.020641  ...
# 4       1.5   0.659698  161.212960       1.0   0.910648  ...
#
#    A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                   1                 10                   3
# ...
