# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %%
from ema_workbench import load_results
from ema_workbench import (Model, RealParameter, ScalarOutcome, MultiprocessingEvaluator, 
                           ema_logging, Constant, Scenario, Policy, CategoricalParameter, IntegerParameter,
                           perform_experiments, SequentialEvaluator)

from ema_workbench.em_framework.evaluators import perform_experiments
from ema_workbench.em_framework.samplers import sample_uncertainties
from ema_workbench.util import ema_logging, utilities
import time

ema_logging.log_to_stderr(ema_logging.INFO)
# Out:
# <Logger EMA (DEBUG)>

# %%
from dike_model_function import DikeNetwork  # @UnresolvedImport
from problem_formulation import get_model_for_problem_formulation

dike_model,  planning_steps = get_model_for_problem_formulation(2) #for now 5 objectives

# %%
# we do not want any policies to run for the base case

policies = [Policy("base case no policy", **{k.name: 0 for k in dike_model.levers})]

# %%
# EMA workbench experiment runs with 1000 experiments
n_scenarios = 1000
with MultiprocessingEvaluator(dike_model) as evaluator:
    results = evaluator.perform_experiments(n_scenarios,
                                            policies)
# Out:
# [MainProcess/INFO] pool started with 8 workers
# [MainProcess/INFO] performing 1000 scenarios * 1 policies * 1 model(s) = 1000 experiments
#   0%|                                       | 1/1000 [00:03<1:04:47,  3.89s/it]Traceback (most recent call last):
#   File "C:\Users\31649\anaconda3\lib\site-packages\ema_workbench\em_framework\callbacks.py", line 246, in _store_outcomes
#     self.results[outcome][case_id,] = outcome_res
# KeyError: 'Dike Investment Costs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\31649\anaconda3\lib\site-packages\ema_workbench\em_framework\ema_multiprocessing.py", line 253, in run
#     self.callback(*result.get())
#   File "C:\Users\31649\anaconda3\lib\site-packages\ema_workbench\em_framework\callbacks.py", line 281, in __call__
#     self._store_outcomes(experiment.experiment_id, outcomes)
#   File "C:\Users\31649\anaconda3\lib\site-packages\ema_workbench\em_framework\callbacks.py", line 260, in _store_outcomes
#     self.results[outcome][:] = np.nan
# ValueError: cannot convert float NaN to integer
# 100%|██████████████████████████████████████| 1000/1000 [07:00<00:00,  2.38it/s]
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool

# %%
#saving the results
utilities.save_results(results, 'results/base_case_5_objectives_no_policy.csv')
# Out:
# [MainProcess/INFO] results saved successfully to C:\Users\31649\Documents\Master\Model-based decisionmaking\epa1361_open-master\final assignment\results\base_case_5_objectives_no_policy.csv

# %%
base_case_results=utilities.load_results('results/base_case_no_policy.csv')
experiments, outcomes = base_case_results
print("The outcomes are:",outcomes.keys())
experiments
# Out:
# [MainProcess/INFO] results loaded successfully from C:\Users\31649\Documents\Master\Model-based decisionmaking\epa1361_open-master\final assignment\results\base_case_no_policy.csv
# The outcomes are: dict_keys(['All Costs', 'Expected Number of Deaths'])
#     A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                       128  250.450267      10.0   0.758363  146.533299
# 1                        13  323.284350      10.0   0.357095   60.664619
# 2                        26  299.125116      10.0   0.499738  294.028353
# 3                        86  261.564482       1.5   0.693134   85.705892
# 4                        83  152.256847       1.0   0.116311  137.727743
# ..                      ...         ...       ...        ...         ...
# 95                       47  196.395447       1.0   0.040617   38.096867
# 96                        9  126.265305      10.0   0.034092  297.554553
# 97                       81  325.609186      10.0   0.423118  342.313629
# 98                       61  330.719745       1.5   0.452689   53.846652
# 99                       20  336.040748       1.5   0.410537  291.956990
#
#    A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0        1.0   0.577455  294.789424       1.0   0.946967  ...
# 1       10.0   0.740797  182.317453       1.0   0.531086  ...
# 2       10.0   0.262845  147.636221      10.0   0.919567  ...
# 3       10.0   0.953460  137.256805       1.0   0.785620  ...
# 4        1.5   0.397146  125.644561       1.5   0.705142  ...
# ..       ...        ...         ...       ...        ...  ...
# 95       1.5   0.700488  311.365602      10.0   0.071726  ...
# 96       1.5   0.765539   85.736320      10.0   0.266582  ...
# 97       1.0   0.290171  224.545079       1.0   0.483978  ...
# 98       1.0   0.794624  160.299027      10.0   0.113147  ...
# 99      10.0   0.565303  251.185339       1.0   0.243879  ...
#
#     A.3_DikeIncrease 2 A.4_DikeIncrease 0  A.4_DikeIncrease 1  \
# 0                    0                  0                   0
# 1                    0                  0                   0
# 2                    0                  0                   0
# 3                    0                  0                   0
# 4                    0                  0                   0
# ..                 ...                ...                 ...
# 95                   0                  0                   0
# 96                   0                  0                   0
# 97                   0                  0                   0
# 98                   0                  0                   0
# 99                   0                  0                   0
#
#     A.4_DikeIncrease 2 A.5_DikeIncrease 0  A.5_DikeIncrease 1  \
# 0                    0                  0                   0
# 1                    0                  0                   0
# 2                    0                  0                   0
# 3                    0                  0                   0
# 4                    0                  0                   0
# ..                 ...                ...                 ...
# 95                   0                  0                   0
# 96                   0                  0                   0
# 97                   0                  0                   0
# 98                   0                  0                   0
# 99                   0                  0                   0
#
#    A.5_DikeIncrease 2 scenario               policy     model
# 0                   0        0  base case no policy  dikesnet
# 1                   0        1  base case no policy  dikesnet
# 2                   0        2  base case no policy  dikesnet
# 3                   0        3  base case no policy  dikesnet
# 4                   0        4  base case no policy  dikesnet
# ..                ...      ...                  ...       ...
# 95                  0       95  base case no policy  dikesnet
# 96                  0       96  base case no policy  dikesnet
# 97                  0       97  base case no policy  dikesnet
# 98                  0       98  base case no policy  dikesnet
# 99                  0       99  base case no policy  dikesnet
#
# [100 rows x 53 columns]
